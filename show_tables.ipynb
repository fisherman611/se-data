# %%
import os 
import sys 
new_cwd = f"{os.getcwd()}/data"
import pandas as pd 
import numpy as np

# %% [markdown]
# ### **User table**

# %%
users = pd.read_csv(f"{new_cwd}/users.csv")
users.head()
# Out:
#    u_id   username                       email  \
# 0     1  alyssa328  evansalyssa328@example.com
# 1     2    ezra809    williamsezra809@mail.com
# 2     3    emma971   wilsonemma971@example.com
# 3     4  daniel759  thompsondaniel759@mail.com
# 4     5  alyssa698   robertsalyssa698@mail.com
#
#                                             password             name  \
# 0  gAAAAABn9NPURNJX71-XoQM6KJvBTZitCfdfvzRjIMRImA...     Alyssa Evans
# 1  gAAAAABn9NPU6H8bmHRCvTwlC6BkLAVyNe6alH96_p_Mpo...    Ezra Williams
# 2  gAAAAABn9NPU6PvA_ndj-lSCruA7iDbR_1YnmS9l1DsGvq...      Emma Wilson
# 3  gAAAAABn9NPUcpkOA219JIfm8C2TOxE7TIx7-WKYCjWk27...  Daniel Thompson
# 4  gAAAAABn9NPUOLP2IJZC0J6X3Ukjofv3ni-nW9nlWYeEfi...   Alyssa Roberts
#
#           dob  gender         date_created
# 0  1982-03-05  Female  2025-02-25 01:46:39
# 1  1993-01-08    Male  2025-01-11 22:24:22
# 2  1985-08-04  Female  2025-03-11 00:32:43
# 3  1986-04-22    Male  2025-01-22 16:03:05
# ...

# %% [markdown]
# ### **Progress Table**

# %%
progress = pd.read_csv(f"{new_cwd}/progress.csv")
progress.head()
# Out:
#    u_id  topic_id  lesson_id  score       status         last_updated
# 0     1         1          1  10000    Completed  2024-12-26 22:19:14
# 1     1         1          2   4380  In Progress  2025-01-09 22:19:14
# 2     1         1          3      0  Not Started  2025-03-08 22:19:14
# 3     1         1          4   8155  In Progress  2025-02-07 22:19:14
# 4     1         1          5  10000    Completed  2024-12-14 22:19:14

# %% [markdown]
# ### **Sentences Table**

# %%
sentences = pd.read_csv(f"{new_cwd}/sentences.csv")
sentences.head()
# Out:
#    s_id                                                eng  \
# 0     1                Come and see me anytime you want to
# 1     2  A word of encouragement during a failure is wo...
# 2     3                      He stood with his feet apart.
# 3     4         I don't see what that has to do with this.
# 4     5                  He is nothing more than a coward.
#
#                                                 viet             topic_name
# 0             Đến và gặp tôi bất cứ lúc nào bạn muốn   Diaries & Daily Life
# 1  Một lời khích lệ trong một thất bại có giá trị...   Diaries & Daily Life
# 2                            Anh đứng cách xa nhau .          Other Hobbies
# 3    Tôi không thấy những gì phải làm với điều này .   Diaries & Daily Life
# 4              Anh ta chẳng hơn gì một kẻ hèn nhát .  News & Social Concern

# %% [markdown]
# ### **Word Table**

# %%
words = pd.read_csv(f"{new_cwd}/words.csv")
words.head()
# Out:
#    w_id  s_id  idx      word               similar_words
# 0     1     1    7       nào    giới, nhầm_lẫn, sản_xuất
# 1     2     1    5    bất_cứ              bởi, sang, mỗi
# 2     3     2    9       hơn                cần, là, mỗi
# 3     4     2    6  thất_bại  vội_vã, thiệt_hại, đau_khổ
# 4     5     3    2      đứng      khích_lệ, Sản_xuất, Vụ

# %% [markdown]
# ### **Topics Table**

# %%
topics = pd.read_csv(f"{new_cwd}/topics.csv")
topics
# Out:
#     topic_id                topic_name  \
# 0          1            Arts & Culture
# 1          2  Business & Entrepreneurs
# 2          3   Celebrity & Pop Culture
# 3          4      Diaries & Daily Life
# 4          5                    Family
# 5          6           Fashion & Style
# 6          7           Film Tv & Video
# 7          8          Fitness & Health
# 8          9             Food & Dining
# 9         10                    Gaming
# 10        11    Learning & Educational
# 11        12                     Music
# 12        13     News & Social Concern
# 13        14             Other Hobbies
# 14        15             Relationships
# 15        16      Science & Technology
# 16        17                    Sports
# 17        18        Travel & Adventure
# 18        19      Youth & Student Life
#
#                                           description
# 0   Discover the language of creativity and expres...
# 1   Learn the key terms and phrases used in the pr...
# ...

# %% [markdown]
# ### **Lessons Table**

# %%
lessons = pd.read_csv(f"{new_cwd}/lessons.csv")
lessons.head()
# Out:
#    topic_id  lesson_id        lesson_type   s_id
# 0         1          1              Vocab  10009
# 1         1          1              Vocab  10967
# 2         1          2  Fill_in_the_blank   2661
# 3         1          2  Fill_in_the_blank   9809
# 4         1          3     Re_order_words   2219
